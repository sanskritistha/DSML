# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset=pd.read_csv("Fraud_Detection.csv")

# %%
dataset.head()
# Out:
#    step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   283   CASH_IN  210329.84  C1159819632     3778062.79      3988392.64
# 1   132  CASH_OUT  215489.19  C1372369468       21518.00            0.00
# 2   355     DEBIT    4431.05  C1059822709       20674.00        16242.95
# 3   135  CASH_OUT  214026.20  C1464960643       46909.73            0.00
# 4   381  CASH_OUT    8858.45   C831134427           0.00            0.00
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud
# 0  C1218876138      1519266.60      1308936.76        0
# 1   C467105520      6345756.55      6794954.89        0
# 2    C76588246        80876.56        85307.61        0
# 3  C1059379810     13467450.36     13681476.56        0
# 4   C579876929      1667180.58      1676039.03        0

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=636262, step=1)

# %%
# view dimensions of dataset
dataset.shape
# Out:
# (636262, 10)

# %%
dataset.info
# Out:
# <bound method DataFrame.info of         step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0        283   CASH_IN  210329.84  C1159819632     3778062.79      3988392.64
# 1        132  CASH_OUT  215489.19  C1372369468       21518.00            0.00
# 2        355     DEBIT    4431.05  C1059822709       20674.00        16242.95
# 3        135  CASH_OUT  214026.20  C1464960643       46909.73            0.00
# 4        381  CASH_OUT    8858.45   C831134427           0.00            0.00
# ...      ...       ...        ...          ...            ...             ...
# 636257   351  CASH_OUT   28761.10   C742050657           0.00            0.00
# 636258   184  CASH_OUT  167820.71   C561181412       62265.00            0.00
# 636259    35   PAYMENT    8898.12  C1773417333       30808.00        21909.88
# 636260   277  CASH_OUT  176147.90  C1423233247       83669.00            0.00
# 636261   304  CASH_OUT   95142.89   C874575079           0.00            0.00
#
#            nameDest  oldbalanceDest  newbalanceDest  isFraud
# 0       C1218876138      1519266.60      1308936.76        0
# 1        C467105520      6345756.55      6794954.89        0
# 2         C76588246        80876.56        85307.61        0
# 3       C1059379810     13467450.36     13681476.56        0
# 4        C579876929      1667180.58      1676039.03        0
# ...             ...             ...             ...      ...
# 636257   C568407561       328534.52       357295.62        0
# 636258  C1852953580       106429.48       274250.18        0
# 636259   M445701551            0.00            0.00        0
# 636260  C1328739120            0.00       176147.90        0
# 636261   C666451134       431380.07       526522.96        0
#
# [636262 rows x 10 columns]>

# %% [markdown]
# Missing Values in variables

# %%
# check missing values in variables

dataset.isnull().sum()
# Out:
# step               0
# type              11
# amount             0
# nameOrig           0
# oldbalanceOrg      1
# newbalanceOrig     0
# nameDest           0
# oldbalanceDest     0
# newbalanceDest    10
# isFraud            0
# dtype: int64

# %%
# Data Preprocessing
x = dataset.drop(columns=["isFraud", "nameOrig", "nameDest"])
y = dataset["isFraud"]

# %%
x=pd.get_dummies(x,drop_first=True) #one hot encoding

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33, random_state = 42)

# %%
print(x_train)
print(y_train)
print(x_test)
print(y_test)
# Out:
#         step     amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 354479   234  512017.03    22560089.19     23072106.22      6358135.36
# 199906   251   33898.58       14603.00            0.00            0.00
# 430163   141   43113.66           0.00            0.00       303749.18
# 121251   352  652752.50           0.00            0.00      2913331.36
# 42843    333    2649.24         190.00            0.00            0.00
# ...      ...        ...            ...             ...             ...
# 110268    47   11283.86        3971.00            0.00            0.00
# 259178   307   36714.36       26643.00            0.00      2586144.38
# 365838   275  228956.90          50.00            0.00            0.00
# 131932   179   27412.88     1183491.23      1210904.11       202164.49
# 121958    17   27798.21      274541.22       246743.01      1691795.12
#
#         newbalanceDest  type_CASH_OUT  type_DEBIT  type_PAYMENT  type_TRANSFER
# 354479      5846118.34          False       False         False          False
# 199906            0.00          False       False          True          False
# 430163       288043.77           True       False         False          False
# 121251      3566083.86           True       False         False          False
# 42843             0.00          False       False          True          False
# ...                ...            ...         ...           ...            ...
# 110268            0.00          False       False          True          False
# 259178      2622858.74           True       False         False          False
# 365838       228956.90           True       False         False          False
# 131932       174751.61          False       False         False          False
# 121958      1937276.40           True       False         False          False
#
# [426295 rows x 10 columns]
# 354479    0
# 199906    0
# 430163    0
# 121251    0
# 42843     0
#          ..
# 110268    0
# 259178    0
# 365838    0
# 131932    0
# 121958    0
# Name: isFraud, Length: 426295, dtype: int64
#         step     amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 492123    37  267289.58      397858.58       130569.00      3664138.94
# 370792   234   52457.64           0.00            0.00            0.00
# 435806   687   35944.26           0.00            0.00            0.00
# 195013   132  152038.27           0.00            0.00      1920325.16
# 388753   349  200053.40           0.00            0.00     10364319.70
# ...      ...        ...            ...             ...             ...
# 305519    14  315729.85           0.00            0.00       328595.79
# 140281    46   63014.66       30190.00            0.00        42032.60
# 440165   138  245344.91       10152.00            0.00       852884.99
# 302148    12  159209.28        4185.49            0.00       163213.14
# 351329   375  401119.75     1619573.77      2020693.52       437547.30
#
#         newbalanceDest  type_CASH_OUT  type_DEBIT  type_PAYMENT  type_TRANSFER
# 492123      3931428.53           True       False         False          False
# 370792            0.00          False       False          True          False
# 435806            0.00          False       False          True          False
# 195013      2072363.43           True       False         False          False
# 388753     10564373.10           True       False         False          False
# ...                ...            ...         ...           ...            ...
# 305519       606307.95           True       False         False          False
# 140281       105047.26           True       False         False          False
# 440165      1098229.90           True       False         False          False
# 302148       322422.41           True       False         False          False
# 351329        36427.55          False       False         False          False
#
# [209967 rows x 10 columns]
# 492123    0
# 370792    0
# 435806    0
# 195013    0
# 388753    0
#          ..
# 305519    0
# 140281    0
# 440165    0
# 302148    0
# 351329    0
# Name: isFraud, Length: 209967, dtype: int64

# %%
# check the shape of X_train and X_test
x_train.shape, x_test.shape
# Out:
# ((426295, 10), (209967, 10))

# %%
# check data types in X_train
x_train.dtypes
# Out:
# step                int64
# amount            float64
# oldbalanceOrg     float64
# newbalanceOrig    float64
# oldbalanceDest    float64
# newbalanceDest    float64
# type_CASH_OUT        bool
# type_DEBIT           bool
# type_PAYMENT         bool
# type_TRANSFER        bool
# dtype: object

# %%
dataset.isnull().sum()
# Out:
# step               0
# type              11
# amount             0
# nameOrig           0
# oldbalanceOrg      1
# newbalanceOrig     0
# nameDest           0
# oldbalanceDest     0
# newbalanceDest    10
# isFraud            0
# dtype: int64

# %%
# import DecisionTreeClassifier

from sklearn.tree import DecisionTreeClassifier

# %%
# instantiate the DecisionTreeClassifier model with criterion gini index
clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=0)
# fit the model
clf_gini.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
# predict the test set result
y_pred_gini=clf_gini.predict(x_test)
x_test
# Out:
#         step     amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 492123    37  267289.58      397858.58       130569.00      3664138.94
# 370792   234   52457.64           0.00            0.00            0.00
# 435806   687   35944.26           0.00            0.00            0.00
# 195013   132  152038.27           0.00            0.00      1920325.16
# 388753   349  200053.40           0.00            0.00     10364319.70
# ...      ...        ...            ...             ...             ...
# 305519    14  315729.85           0.00            0.00       328595.79
# 140281    46   63014.66       30190.00            0.00        42032.60
# 440165   138  245344.91       10152.00            0.00       852884.99
# 302148    12  159209.28        4185.49            0.00       163213.14
# 351329   375  401119.75     1619573.77      2020693.52       437547.30
#
#         newbalanceDest  type_CASH_OUT  type_DEBIT  type_PAYMENT  type_TRANSFER
# 492123      3931428.53           True       False         False          False
# 370792            0.00          False       False          True          False
# 435806            0.00          False       False          True          False
# 195013      2072363.43           True       False         False          False
# 388753     10564373.10           True       False         False          False
# ...                ...            ...         ...           ...            ...
# 305519       606307.95           True       False         False          False
# 140281       105047.26           True       False         False          False
# 440165      1098229.90           True       False         False          False
# 302148       322422.41           True       False         False          False
# 351329        36427.55          False       False         False          False
#
# [209967 rows x 10 columns]

# %%
# check accuracy score  with criterion gini index
from sklearn.metrics import accuracy_score

print('Model accuracy score with criterion gini index: {0:0.4f}'. format(accuracy_score(y_test, y_pred_gini)))
# Out:
# Model accuracy score with criterion gini index: 0.9989

# %%
# compare the train-set and train-set accuracy
y_pred_train_gini = clf_gini.predict(x_train)
y_pred_train_gini
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)
